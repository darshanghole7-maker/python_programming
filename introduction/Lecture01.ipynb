# %%
# introduction to python programming 
'''
Data of python programming
1. int : 28
2. float : 3.14
3. string : any text value or text form 
4. bool : True / false
5. list : [1,1.222,'india',true,[10],(2){}]
6. tuple : [1,1.222,'india',true,[10],(2){}]
7. dictionary : {'country':['india','usa']}
8. set : {}
9. None 
--------------------------------------------------------------------------------------
# Data stuctures in python programming

1. list :muable
2. tuple : immutable
3. dictionary : mutable
4. set : mutable
--------------------------------------------------------------------------------------
'''

print('Hello world')


name = "Darshan"
domain = "DSDA"
experience = 1

# formated string
print(f'my name is {name} and my domain is {domain} and my experience is {experience}')

# %%
print('Hello world')


name = "Darshan"
domain = "DSDA"
experience = 1

# formated string
print(f'my name is {name} and my domain is {domain} and my experience is {experience}')

# %%
# asking user to input the value
name = input("Enter your name: ")
print(f'my name is {name}')

# %%
age = input("Enter your age ")
print(type(age)')

# %%
# concept of typecasting
age = int(input("Enter your age "))

print(type(age))

# %%
# variable assignment
 ''' 
 num = 100 is considered as valid variable assignment
 
 '''

num1 = 100
num2 = 200


_num = 200
_1num = 300

# multi-variable assignment
num3, num4 = 400, 500

# %%
# multi-variable assignment
num3, num4 = 400, 500

# %%
# concept of indexing and slicing 
a= "Hello world"

print(a[0::2])      # a [start:stop:step]

# %%
# write a program whether the entered string is palindrome or not


string = input("Enter a string: ")

string1 = string[::-1]   #reverse the string

if string == string1:


    print("the given string is palindrome")
else:
    print("the given string is not a palindrome")

# %%
marks = float(input("Enter your marks: "))

if marks >= 90:
    print("A grade")    
elif marks >= 80:
    print("B grade")
elif marks >= 60:
    print("C grade")
elif marks >= 40:
    print("D grade")
else: 
    print("Fail")

# %%
acc_id = int(input("Enter your account id: "))
passcode = input("Enter your passcode: ")

if acc_id == 12345 and passcode == "sbi123":
      print("Login successful")   
else:
      print("Login failed")

# %%
train_name = string("Enter your train name: ")
bookings_status = int(input("Enter your booking status: "))
status = "confirmed"

if bookings_status == "confirmed":
    
    print(f'Your booking status is {status} for the train {train_name}')
    no_of_bookings = int(input("Enter the number of bookings: "))
